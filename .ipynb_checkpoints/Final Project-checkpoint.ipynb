# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df=pd.read_excel("synthetic_click_data_v4.xlsx")

# %%
df.head()
# Out:
#         ip_address   device         browser           click_time  \
# 0    170.208.20.96   Server       PhantomJS  2025-01-09 04:29:54
# 1     188.83.33.85  Desktop  HeadlessChrome  2025-02-17 02:35:18
# 2      54.50.82.19   Mobile          Safari  2025-01-11 15:05:05
# 3    253.209.61.69  Desktop         Firefox  2025-01-16 02:19:17
# 4  216.183.131.190  Desktop          Safari  2025-03-19 20:57:23
#
#       session_end_time geo_location  click_frequency  session_duration  \
# 0  2025-01-09 04:30:52        India               15                58
# 1  2025-02-17 02:36:52       Canada                5                94
# 2  2025-01-11 15:06:04       Canada                2                59
# 3  2025-01-16 02:19:24        India                3                 7
# 4  2025-03-19 20:57:48       Canada               10                25
#
#        referrer  mouse_movements  click_pattern_count  scroll_depth  \
# 0    google.com              167                   10            36
# 1  facebook.com              153                    8            16
# 2   twitter.com              304                    8             2
# 3      bing.com              185                    4            53
# 4   twitter.com               39                   10            25
#
#    time_on_page  num_pages_visited  click_interval_std  is_bot
# 0            47                 20            3.336618       0
# 1           106                  8           17.800871       0
# 2            47                 16            1.359790       0
# 3             7                 12            0.655960       0
# 4            25                  7            1.353053       1

# %%
df.isnull().sum()
# Out:
# ip_address                0
# device                    0
# browser                   0
# click_time                0
# session_end_time          0
# geo_location              0
# click_frequency           0
# session_duration          0
# referrer               3324
# mouse_movements           0
# click_pattern_count       0
# scroll_depth              0
# time_on_page              0
# num_pages_visited         0
# click_interval_std        0
# is_bot                    0
# dtype: int64

# %%
df.shape
# Out:
# (20000, 16)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             ip_address   device         browser           click_time  \
# 0        170.208.20.96   Server       PhantomJS  2025-01-09 04:29:54
# 1         188.83.33.85  Desktop  HeadlessChrome  2025-02-17 02:35:18
# 2          54.50.82.19   Mobile          Safari  2025-01-11 15:05:05
# 3        253.209.61.69  Desktop         Firefox  2025-01-16 02:19:17
# 4      216.183.131.190  Desktop          Safari  2025-03-19 20:57:23
# ...                ...      ...             ...                  ...
# 19995    49.254.162.80  Desktop            Edge  2025-01-10 09:32:50
# 19996  254.175.136.213   Mobile       PhantomJS  2025-01-13 03:32:50
# 19997   144.193.18.100  Desktop            Edge  2025-02-26 19:23:31
# 19998   219.151.224.41   Mobile         Firefox  2025-03-15 05:38:18
# 19999  197.200.250.217   Tablet  HeadlessChrome  2025-03-31 23:23:21
#
#           session_end_time geo_location  click_frequency  session_duration  \
# 0      2025-01-09 04:30:52        India               15                58
# 1      2025-02-17 02:36:52       Canada                5                94
# 2      2025-01-11 15:06:04       Canada                2                59
# 3      2025-01-16 02:19:24        India                3                 7
# 4      2025-03-19 20:57:48       Canada               10                25
# ...                    ...          ...              ...               ...
# 19995  2025-01-10 09:33:58          USA                1                68
# 19996  2025-01-13 03:34:38    Australia                5               108
# 19997  2025-02-26 19:24:31           UK               14                60
# 19998  2025-03-15 05:39:36    Australia               16                78
# 19999  2025-03-31 23:23:50        India                2                29
#
#            referrer  mouse_movements  click_pattern_count  scroll_depth  \
# 0        google.com              167                   10            36
# 1      facebook.com              153                    8            16
# 2       twitter.com              304                    8             2
# 3          bing.com              185                    4            53
# 4       twitter.com               39                   10            25
# ...             ...              ...                  ...           ...
# 19995   twitter.com               98                    5            76
# 19996           NaN               25                    8            65
# 19997   twitter.com               40                    5            46
# 19998  facebook.com               15                    1            72
# 19999    google.com               31                    7            51
#
#        time_on_page  num_pages_visited  click_interval_std  is_bot
# 0                47                 20            3.336618       0
# 1               106                  8           17.800871       0
# 2                47                 16            1.359790       0
# 3                 7                 12            0.655960       0
# 4                25                  7            1.353053       1
# ...             ...                ...                 ...     ...
# 19995            61                 10            1.248905       0
# 19996           108                  4           17.456842       1
# 19997            60                  3            4.719405       1
# 19998            93                  9            5.748731       0
# 19999            26                 17            0.159395       0
#
# [20000 rows x 16 columns]>

# %%
df['is_bot'].value_counts()
# Out:
# is_bot
# 0    15251
# 1     4749
# Name: count, dtype: int64

# %%
df['referrer'].value_counts()
# Out:
# referrer
# bing.com         3397
# twitter.com      3377
# google.com       3355
# facebook.com     3299
# instagram.com    3248
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# ip_address              object
# device                  object
# browser                 object
# click_time              object
# session_end_time        object
# geo_location            object
# click_frequency          int64
# session_duration         int64
# referrer                object
# mouse_movements          int64
# click_pattern_count      int64
# scroll_depth             int64
# time_on_page             int64
# num_pages_visited        int64
# click_interval_std     float64
# is_bot                   int64
# dtype: object

# %%
label_encoders = {}

# Loop through each column and apply Label Encoding if the column is of object type
for col in df.columns:
    if df[col].dtype == 'object':
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))
        label_encoders[col] = le  # Save the encoder for potential inverse transformation

# %%
df.dtypes
# Out:
# ip_address               int64
# device                   int64
# browser                  int64
# click_time               int64
# session_end_time         int64
# geo_location             int64
# click_frequency          int64
# session_duration         int64
# referrer                 int64
# mouse_movements          int64
# click_pattern_count      int64
# scroll_depth             int64
# time_on_page             int64
# num_pages_visited        int64
# click_interval_std     float64
# is_bot                   int64
# dtype: object

# %%
x=df.drop('is_bot',axis=1)
y=df['is_bot']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=0,test_size=0.3)
model=LogisticRegression()
model.fit(xtrain,ytrain)
ypred=model.predict(xtest)
accuracy_score(ypred,ytest)
# Out:
# C:\Users\viren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7928333333333333

# %%
df.corr()
# Out:
#                      ip_address    device   browser  click_time  \
# ip_address             1.000000  0.002290 -0.000744    0.006781
# device                 0.002290  1.000000 -0.000312   -0.000534
# browser               -0.000744 -0.000312  1.000000   -0.001111
# click_time             0.006781 -0.000534 -0.001111    1.000000
# session_end_time       0.006780 -0.000532 -0.001112    1.000000
# geo_location          -0.003599  0.002433  0.005581   -0.000478
# click_frequency       -0.006065  0.001545 -0.001026    0.003103
# session_duration       0.000291 -0.005564  0.002540    0.006948
# referrer              -0.005437 -0.003438 -0.001242   -0.003874
# mouse_movements       -0.010085 -0.003743  0.003221    0.000871
# click_pattern_count    0.002271 -0.006716 -0.012142   -0.007745
# scroll_depth           0.005444 -0.004803  0.002799   -0.005173
# time_on_page           0.003579 -0.005199  0.001548    0.004957
# num_pages_visited      0.006268  0.002283  0.001693    0.003599
# click_interval_std     0.002401 -0.004974 -0.008623    0.008306
# is_bot                 0.018463  0.000431 -0.010001   -0.015482
#
#                      session_end_time  geo_location  click_frequency  \
# ip_address                   0.006780     -0.003599        -0.006065
# device                      -0.000532      0.002433         0.001545
# browser                     -0.001112      0.005581        -0.001026
# click_time                   1.000000     -0.000478         0.003103
# session_end_time             1.000000     -0.000481         0.003103
# geo_location                -0.000481      1.000000         0.001535
# click_frequency              0.003103      0.001535         1.000000
# session_duration             0.006961     -0.000051        -0.018439
# referrer                    -0.003875      0.011759         0.008192
# mouse_movements              0.000871      0.008346        -0.006291
# click_pattern_count         -0.007745     -0.004002        -0.000014
# scroll_depth                -0.005175     -0.005487         0.005171
# time_on_page                 0.004970      0.001040        -0.018620
# num_pages_visited            0.003597      0.009155        -0.000780
# click_interval_std           0.008313     -0.001016        -0.044333
# is_bot                      -0.015480      0.005756         0.001287
#
#                      session_duration  referrer  mouse_movements  \
# ip_address                   0.000291 -0.005437        -0.010085
# device                      -0.005564 -0.003438        -0.003743
# browser                      0.002540 -0.001242         0.003221
# click_time                   0.006948 -0.003874         0.000871
# session_end_time             0.006961 -0.003875         0.000871
# geo_location                -0.000051  0.011759         0.008346
# click_frequency             -0.018439  0.008192        -0.006291
# session_duration             1.000000  0.003548        -0.010954
# referrer                     0.003548  1.000000        -0.000519
# mouse_movements             -0.010954 -0.000519         1.000000
# click_pattern_count          0.003053 -0.002094         0.002709
# scroll_depth                -0.008869 -0.008005        -0.002053
# time_on_page                 0.978044  0.005286        -0.011578
# num_pages_visited            0.001573 -0.008181         0.165015
# click_interval_std           0.550280 -0.004990        -0.009103
# is_bot                       0.010735 -0.003960        -0.354872
#
#                      click_pattern_count  scroll_depth  time_on_page  \
# ip_address                      0.002271      0.005444      0.003579
# device                         -0.006716     -0.004803     -0.005199
# browser                        -0.012142      0.002799      0.001548
# click_time                     -0.007745     -0.005173      0.004957
# session_end_time               -0.007745     -0.005175      0.004970
# geo_location                   -0.004002     -0.005487      0.001040
# click_frequency                -0.000014      0.005171     -0.018620
# session_duration                0.003053     -0.008869      0.978044
# referrer                       -0.002094     -0.008005      0.005286
# mouse_movements                 0.002709     -0.002053     -0.011578
# click_pattern_count             1.000000      0.002452      0.003761
# scroll_depth                    0.002452      1.000000     -0.007408
# time_on_page                    0.003761     -0.007408      1.000000
# num_pages_visited              -0.007123      0.017739     -0.000681
# click_interval_std             -0.004926     -0.011004      0.538986
# is_bot                          0.009732     -0.002520      0.013947
#
#                      num_pages_visited  click_interval_std    is_bot
# ip_address                    0.006268            0.002401  0.018463
# device                        0.002283           -0.004974  0.000431
# browser                       0.001693           -0.008623 -0.010001
# click_time                    0.003599            0.008306 -0.015482
# session_end_time              0.003597            0.008313 -0.015480
# geo_location                  0.009155           -0.001016  0.005756
# click_frequency              -0.000780           -0.044333  0.001287
# session_duration              0.001573            0.550280  0.010735
# referrer                     -0.008181           -0.004990 -0.003960
# mouse_movements               0.165015           -0.009103 -0.354872
# click_pattern_count          -0.007123           -0.004926  0.009732
# scroll_depth                  0.017739           -0.011004 -0.002520
# time_on_page                 -0.000681            0.538986  0.013947
# num_pages_visited             1.000000            0.004993 -0.336187
# click_interval_std            0.004993            1.000000  0.002317
# is_bot                       -0.336187            0.002317  1.000000
